# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")

# %%
data1 = pd.read_excel('A549_1497.xlsx')
data1.head()
# Out:
#    Conc. (uM)   Drug  Glucose consumed
# 0         0.0  Empty         93.283190
# 1         0.0  Empty         97.211920
# 2         0.0  Empty        109.504890
# 3         2.5  Empty        115.205420
# 4         2.5  Empty        145.323123

# %%
data2 = pd.read_excel('A549_2136.xlsx')
data2.head()
# Out:
#    Conc. (uM)   Drug  Glucose consumed
# 0         0.0  Empty         97.101547
# 1         0.0  Empty         99.757595
# 2         0.0  Empty        103.140858
# 3         2.5  Empty        126.595740
# 4         2.5  Empty        122.260641

# %%
data3 = pd.read_excel('A549_2305.xlsx')
data3.head()
# Out:
#    Conc. (uM)   Drug  Glucose consumed
# 0         0.0  Empty         92.093868
# 1         0.0  Empty         84.844367
# 2         0.0  Empty        123.061765
# 3         2.5  Empty        142.475925
# 4         2.5  Empty        122.242984

# %%
data4 = pd.read_excel('A549_2422.xlsx')
data4.head()
# Out:
#    Conc. (uM)   Drug  Glucose consumed
# 0         0.0  Empty        103.542506
# 1         0.0  Empty         90.097380
# 2         0.0  Empty        106.360114
# 3         2.5  Empty        147.525236
# 4         2.5  Empty        149.643946

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

colors = ['#d9d9d9', '#2171b5', '#6baed6', '#bdd7e7']

sns.set_palette(sns.color_palette(colors))

sns.barplot(x="Drug", y="Glucose consumed", hue="Conc. (uM)", data=data1, capsize=.1, ci="sd")
sns.swarmplot(x="Drug", y="Glucose consumed", data=data1, hue="Conc. (uM)", color="0.2", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.11, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=40)
plt.yticks(size=40)


plt.xlabel("1497", size=40)
plt.ylabel("Glucose consumed", size=40)

plt.savefig('Glucose_A549_1497_6hr.pdf', dpi = 300)

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

colors = ['#d9d9d9', '#2171b5', '#6baed6', '#bdd7e7']

sns.set_palette(sns.color_palette(colors))

sns.barplot(x="Drug", y="Glucose consumed", hue="Conc. (uM)", data=data2, capsize=.1, ci="sd")
sns.swarmplot(x="Drug", y="Glucose consumed", data=data2, hue="Conc. (uM)", color="0.2", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.11, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=40)
plt.yticks(size=40)


plt.xlabel("2136", size=40)
plt.ylabel("Glucose consumed", size=40)

plt.savefig('Glucose_A549_2136_6hr.pdf', dpi = 300)

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

colors = ['#d9d9d9', '#2171b5', '#6baed6', '#bdd7e7']

sns.set_palette(sns.color_palette(colors))

sns.barplot(x="Drug", y="Glucose consumed", hue="Conc. (uM)", data=data3, capsize=.1, ci="sd")
sns.swarmplot(x="Drug", y="Glucose consumed", data=data3, hue="Conc. (uM)", color="0.2", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.11, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=40)
plt.yticks(size=40)


plt.xlabel("2305", size=40)
plt.ylabel("Glucose consumed", size=40)

plt.savefig('Glucose_A549_2305_6hr.pdf', dpi = 300)

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

colors = ['#d9d9d9', '#2171b5', '#6baed6', '#bdd7e7']

sns.set_palette(sns.color_palette(colors))

sns.barplot(x="Drug", y="Glucose consumed", hue="Conc. (uM)", data=data4, capsize=.1, ci="sd")
sns.swarmplot(x="Drug", y="Glucose consumed", data=data4, hue="Conc. (uM)", color="0.2", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.11, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=40)
plt.yticks(size=40)


plt.xlabel("2422", size=40)
plt.ylabel("Glucose consumed", size=40)

plt.savefig('Glucose_A549_2422_6hr.pdf', dpi = 300)
