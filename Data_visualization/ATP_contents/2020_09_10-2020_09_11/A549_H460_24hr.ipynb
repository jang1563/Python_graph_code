# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")

# %%
data1 = pd.read_excel('A549_24hr.xlsx')
data1.head()
# Out:
#    Conc. (nM) Cell line  Time (hr)  Drug  ATP contents
# 0         0.0      A549         24  1497    105.375383
# 1         0.0      A549         24  1497     98.725741
# 2         0.0      A549         24  1497     95.898876
# 3         2.5      A549         24  1497     82.673136
# 4         2.5      A549         24  1497     78.703269

# %%
data2 = pd.read_excel('H460_24hr.xlsx')
data2.head()
# Out:
#    Conc. (nM) Cell line  Time (hr)  Drug  ATP contents
# 0         0.0      H460         24  1497    103.919698
# 1         0.0      H460         24  1497    100.493079
# 2         0.0      H460         24  1497     95.587222
# 3         2.5      H460         24  1497    116.706086
# 4         2.5      H460         24  1497    106.433941

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

colors = ['#636363', '#2171b5', '#6baed6', '#bdd7e7']

sns.set_palette(sns.color_palette(colors))

sns.barplot(x="Drug", y="ATP contents", hue="Conc. (nM)", data=data1, capsize=.1, ci="sd")
sns.swarmplot(x="Drug", y="ATP contents", data=data1, hue="Conc. (nM)", color="0.2", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.11, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=40)
plt.yticks(size=40)


plt.xlabel("Drug", size=40)
plt.ylabel("ATP contents", size=40)

plt.savefig('ATP_A549_drug.pdf', dpi = 300)

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

colors = ['#636363', '#2171b5', '#6baed6', '#bdd7e7']

sns.set_palette(sns.color_palette(colors))

sns.barplot(x="Drug", y="ATP contents", hue="Conc. (nM)", data=data2, capsize=.1, ci="sd")
sns.swarmplot(x="Drug", y="ATP contents", hue="Conc. (nM)", data=data2, color="0.2", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.11, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=40)
plt.yticks(size=40)


plt.xlabel("Drug", size=40)
plt.ylabel("ATP contents", size=40)

plt.savefig('ATP_H460_drug.pdf', dpi = 300)
