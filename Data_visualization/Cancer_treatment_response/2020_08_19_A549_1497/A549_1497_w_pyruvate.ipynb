# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")

# %%
data = pd.read_excel('A549_analysis.xlsx')
data.head()
# Out:
#    Conc. (uM) Cell line  Cell confluence
# 0       0.000     Empty        99.672608
# 1       0.000     Empty       105.638414
# 2       0.000     Empty        99.527101
# 3       0.000     Empty        95.161877
# 4       0.625     Empty        84.394325

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

sns.barplot(x="Conc. (uM)", y="Cell confluence", data=data, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Conc. (uM)", y="Cell confluence", data=data, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.15, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Conc. (uM)", size=40)
plt.ylabel("Confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('1497', fontsize=40)
plt.savefig('A549_1497_with_pyruvate_confluence.pdf', dpi = 300)

# %%
data1 = pd.read_excel('A549_analysis_no_pyruvate.xlsx')
data1.head()
# Out:
#    Conc. (uM) Cell line  Cell confluence
# 0       0.000     Empty       106.035665
# 1       0.000     Empty        98.491084
# 2       0.000     Empty        89.026063
# 3       0.000     Empty       106.447188
# 4       0.625     Empty        78.463649

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

sns.barplot(x="Conc. (uM)", y="Cell confluence", data=data1, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Conc. (uM)", y="Cell confluence", data=data1, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.15, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Conc. (uM)", size=40)
plt.ylabel("Confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('1497', fontsize=40)
plt.savefig('A549_1497_without_pyruvate_confluence.pdf', dpi = 300)
