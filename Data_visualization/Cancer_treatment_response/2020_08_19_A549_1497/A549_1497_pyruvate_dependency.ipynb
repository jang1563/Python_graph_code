# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")

# %%
data = pd.read_excel('A549_analysis_sodium_pyruvate_dependency.xlsx')
data.head()
# Out:
#    Conc. (uM)           Cell line  Cell confluence
# 0       0.000  Empty; w/ pyruvate        99.672608
# 1       0.000  Empty; w/ pyruvate       105.638414
# 2       0.000  Empty; w/ pyruvate        99.527101
# 3       0.000  Empty; w/ pyruvate        95.161877
# 4       0.625  Empty; w/ pyruvate        84.394325

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

sns.barplot(x="Conc. (uM)", y="Cell confluence", data=data, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Conc. (uM)", y="Cell confluence", data=data, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.35, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Conc. (uM)", size=40)
plt.ylabel("Confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('1497', fontsize=40)
plt.savefig('A549_1497_pyruvate_dependency_confluence.pdf', dpi = 300)
