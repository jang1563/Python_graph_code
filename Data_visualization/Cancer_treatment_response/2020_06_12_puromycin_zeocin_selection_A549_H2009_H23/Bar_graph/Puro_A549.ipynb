# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")


data = pd.read_excel('Puro_A549.xlsx')

# %%
data.head()
# Out:
#    Conc. (ug/ml)  Cell confluence
# 0            0.0         0.942669
# 1            0.5         0.041950
# 2            1.0         0.031762
# 3            4.0         0.025170
# 4            8.0         0.018578

# %%
sns.barplot(x="Conc. (ug/ml)", y="Cell confluence", data=data, capsize=.3, ci="sd")
sns.swarmplot(x="Conc. (ug/ml)", y="Cell confluence", data=data, color="0", alpha=.35)

plt.show()

# %%
sns.barplot(x="Conc. (ug/ml)", y="Cell confluence", data=data, capsize=.3, ci="sd")
sns.swarmplot(x="Conc. (ug/ml)", y="Cell confluence", data=data, color="0", alpha=.35)

plt.title('Puromycin with A549', fontsize=20)
plt.savefig('Puromycin with A549', dpi = 300)
