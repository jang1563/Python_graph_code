# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")


data = pd.read_excel('Zeo_A549.xlsx')

# %%
data.head()
# Out:
#    Conc. (ug/ml)  Cell confluence
# 0              0         0.997911
# 1             50         0.131579
# 2            100         0.069340
# 3            200         0.050961
# 4            400         0.038847

# %%
sns.barplot(x="Conc. (ug/ml)", y="Cell confluence", data=data, capsize=.3, ci="sd")
sns.swarmplot(x="Conc. (ug/ml)", y="Cell confluence", data=data, color="0", alpha=.35)

plt.show()

# %%
sns.barplot(x="Conc. (ug/ml)", y="Cell confluence", data=data, capsize=.3, ci="sd")
sns.swarmplot(x="Conc. (ug/ml)", y="Cell confluence", data=data, color="0", alpha=.35)

plt.title('Zeoycin with A549', fontsize=20)
plt.savefig('Zeocin with A549', dpi = 300)
