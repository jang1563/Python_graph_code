# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")


data = pd.read_excel('Zeo_H23.xlsx')

# %%
data.head()
# Out:
#    Conc. (ug/ml)  Cell confluence
# 0              0         0.990746
# 1             50         0.529668
# 2            100         0.505716
# 3            200         0.483941
# 4            400         0.501905

# %%
sns.barplot(x="Conc. (ug/ml)", y="Cell confluence", data=data, capsize=.3, ci="sd")
sns.swarmplot(x="Conc. (ug/ml)", y="Cell confluence", data=data, color="0", alpha=.35)

plt.show()

# %%
sns.barplot(x="Conc. (ug/ml)", y="Cell confluence", data=data, capsize=.3, ci="sd")
sns.swarmplot(x="Conc. (ug/ml)", y="Cell confluence", data=data, color="0", alpha=.35)

plt.title('Zeoycin with H23', fontsize=20)
plt.savefig('Zeocin with H23', dpi = 300)
