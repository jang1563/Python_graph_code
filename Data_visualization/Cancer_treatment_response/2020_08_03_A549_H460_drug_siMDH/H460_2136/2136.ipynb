# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")
c

# %%
data1 = pd.read_excel('H460_2136_1_1.xlsx')
data1.head()
# Out:
#    Conc. (uM) Cell line  Cell confluence
# 0       0.000     Empty       108.359021
# 1       0.000     Empty       102.411605
# 2       0.000     Empty       103.209429
# 3       0.000     Empty       104.660018
# 4       0.625     Empty        88.123300

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

sns.barplot(x="Conc. (uM)", y="Cell confluence", data=data1, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Conc. (uM)", y="Cell confluence", data=data1, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.2, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=30)
plt.yticks(size=30)

plt.xlabel("Conc. (uM)", size=40)
plt.ylabel("Cell confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('2136 growth inhibition', fontsize=30)
plt.savefig('2136 growth inhibition_conc.pdf', dpi = 300)

# %%
data2 = pd.read_excel('H460_2136_1_2.xlsx')
data2.head()
# Out:
#    Conc. (uM) Cell line  Cell confluence
# 0       0.000     Empty        98.403630
# 1       0.000     Empty        93.631322
# 2       0.000     Empty       103.579230
# 3       0.000     Empty       104.385818
# 4       0.625     Empty        80.188204

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

sns.barplot(x="Conc. (uM)", y="Cell confluence", data=data2, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Conc. (uM)", y="Cell confluence", data=data2, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.2, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=30)
plt.yticks(size=30)

plt.xlabel("Conc. (uM)", size=40)
plt.ylabel("Cell confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('2136 growth inhibition', fontsize=30)
plt.savefig('2136_1_2 growth inhibition_conc.pdf', dpi = 300)

# %%
data3 = pd.read_excel('H460_2136_2.xlsx')
data3.head()
# Out:
#    Conc. (uM) Cell line  Cell confluence
# 0       0.000     Empty       100.281857
# 1       0.000     Empty       100.578549
# 2       0.000     Empty        99.747812
# 3       0.000     Empty        99.391782
# 4       0.625     Empty        97.789645

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

sns.barplot(x="Conc. (uM)", y="Cell confluence", data=data3, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Conc. (uM)", y="Cell confluence", data=data3, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.2, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=30)
plt.yticks(size=30)

plt.xlabel("Conc. (uM)", size=40)
plt.ylabel("Cell confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('2136 growth inhibition', fontsize=30)
plt.savefig('2136_2 growth inhibition_conc.pdf', dpi = 300)

# %%
data4 = pd.read_excel('H460_2136_2_nor.xlsx')
data4.head()
# Out:
#    Conc. (uM) Cell line  Cell confluence
# 0       0.000     Empty       100.281857
# 1       0.000     Empty       100.578549
# 2       0.000     Empty        99.747812
# 3       0.000     Empty        99.391782
# 4       0.625     Empty        97.789645

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

sns.barplot(x="Conc. (uM)", y="Cell confluence", data=data4, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Conc. (uM)", y="Cell confluence", data=data4, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.2, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=30)
plt.yticks(size=30)

plt.xlabel("Conc. (uM)", size=40)
plt.ylabel("Cell confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('2136 growth inhibition', fontsize=30)
plt.savefig('2136_2 growth inhibition_conc_nor.pdf', dpi = 300)
