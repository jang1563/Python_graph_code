# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")


data1 = pd.read_excel('Phenformin_24hr_data.xlsx')
data1.head()
# Out:
#    Conc. (mM) Cell line  Cell confluence
# 0      0.0000     Empty        93.333333
# 1      0.0000     Empty        91.764706
# 2      0.0000     Empty       112.941176
# 3      0.0000     Empty       101.960784
# 4      0.0625     Empty        90.196078

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(16,12))

sns.barplot(x="Cell line", y="Cell confluence", data=data1, hue="Conc. (mM)", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Cell line", y="Cell confluence", data=data1, color="0.2", hue="Conc. (mM)", size=10, dodge=True)


plt.legend(bbox_to_anchor=(1.16, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='30')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Cell line", size=40)
plt.ylabel("Cell confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('Phenformin growth inhibition', fontsize=40)
plt.savefig('Phenformin growth inhibition 24 hr.pdf', dpi = 300)

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(16,12))

sns.barplot(x="Conc. (mM)", y="Cell confluence", data=data1, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Conc. (mM)", y="Cell confluence", data=data1, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.2, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='30')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Conc. (mM)", size=40)
plt.ylabel("Cell confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('Phenformin growth inhibition', fontsize=40)
plt.savefig('Phenformin growth inhibition 24 hr_conc.pdf', dpi = 300)

# %%
data2 = pd.read_excel('Phenformin_48hr_data.xlsx')
data2.head()
# Out:
#    Conc. (mM) Cell line  Cell confluence
# 0     0.00000     Empty        86.468647
# 1     0.00000     Empty       100.000000
# 2     0.00000     Empty       110.891089
# 3     0.00000     Empty       102.640264
# 4     0.03125     Empty        45.214521

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(16,12))

sns.barplot(x="Cell line", y="Cell confluence", data=data2, hue="Conc. (mM)", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Cell line", y="Cell confluence", data=data2, color="0.2", hue="Conc. (mM)", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.2, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='30')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Cell line", size=40)
plt.ylabel("Cell confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('Phenformin growth inhibition', fontsize=40)
plt.savefig('Phenformin growth inhibition 48 hr.pdf', dpi = 300)

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(16,12))

sns.barplot(x="Conc. (mM)", y="Cell confluence", data=data2, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Conc. (mM)", y="Cell confluence", data=data2, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.2, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='30')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Conc. (mM)", size=40)
plt.ylabel("Cell confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('Phenformin growth inhibition', fontsize=30)
plt.savefig('Phenformin growth inhibition 48 hr_conc.pdf', dpi = 300)

# %%
data3 = pd.read_excel('Phenformin_72hr_data.xlsx')
data3.head()
# Out:
#    Conc. (mM) Cell line  Cell confluence
# 0     0.00000     Empty        95.102294
# 1     0.00000     Empty        95.102294
# 2     0.00000     Empty       100.309981
# 3     0.00000     Empty       109.485431
# 4     0.03125     Empty        34.965902

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(16,12))

sns.barplot(x="Cell line", y="Cell confluence", data=data3, hue="Conc. (mM)", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Cell line", y="Cell confluence", data=data3, color="0.2", hue="Conc. (mM)", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.2, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='30')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Cell line", size=40)
plt.ylabel("Cell confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('Phenformin growth inhibition', fontsize=30)
plt.savefig('Phenformin growth inhibition 72 hr.pdf', dpi = 300)

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(16,12))

sns.barplot(x="Conc. (mM)", y="Cell confluence", data=data3, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Conc. (mM)", y="Cell confluence", data=data3, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.2, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='30')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Conc. (mM)", size=40)
plt.ylabel("Cell confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('Phenformin growth inhibition', fontsize=30)
plt.savefig('Phenformin growth inhibition 72 hr_conc.pdf', dpi = 300)

# %%
data4 = pd.read_excel('Phenformin_24hr_normalize.xlsx')
data4.head()
# Out:
#    Conc. (mM) Cell line  Time (hr)  Cell confluence
# 0      0.0000     Empty         24        93.333333
# 1      0.0000     Empty         24        91.764706
# 2      0.0000     Empty         24       112.941176
# 3      0.0000     Empty         24       101.960784
# 4      0.0625     Empty         24        90.196078

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(16,12))

sns.barplot(x="Cell line", y="Cell confluence", data=data4, hue="Conc. (mM)", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Cell line", y="Cell confluence", data=data4, color="0.2", hue="Conc. (mM)", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.2, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='30')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Cell line", size=40)
plt.ylabel("Cell confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('Phenformin growth inhibition', fontsize=30)
plt.savefig('Phenformin growth inhibition 24 hr_nor.pdf', dpi = 300)

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(16,12))

sns.barplot(x="Conc. (mM)", y="Cell confluence", data=data4, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Conc. (mM)", y="Cell confluence", data=data4, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.2, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='30')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Conc. (mM)", size=40)
plt.ylabel("Cell confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('Phenformin growth inhibition', fontsize=30)
plt.savefig('Phenformin growth inhibition 24 hr_conc_nor.pdf', dpi = 300)

# %%
data5 = pd.read_excel('Phenformin_48hr_normalize.xlsx')
data5.head()
# Out:
#    Conc. (mM) Cell line  Time (hr)  Cell confluence
# 0     0.00000     Empty         48        86.468647
# 1     0.00000     Empty         48       100.000000
# 2     0.00000     Empty         48       110.891089
# 3     0.00000     Empty         48       102.640264
# 4     0.03125     Empty         48        45.214521

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(16,12))

sns.barplot(x="Cell line", y="Cell confluence", data=data5, hue="Conc. (mM)", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Cell line", y="Cell confluence", data=data5, color="0.2", hue="Conc. (mM)", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.2, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='30')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Cell line", size=40)
plt.ylabel("Cell confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('Phenformin growth inhibition', fontsize=30)
plt.savefig('Phenformin growth inhibition 48 hr_nor.pdf', dpi = 300)

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(16,12))

sns.barplot(x="Conc. (mM)", y="Cell confluence", data=data5, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Conc. (mM)", y="Cell confluence", data=data5, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.2, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='30')

plt.xticks(size=35)
plt.yticks(size=35)

plt.xlabel("Conc. (mM)", size=40)
plt.ylabel("Cell confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('Phenformin growth inhibition', fontsize=30)
plt.savefig('Phenformin growth inhibition 48 hr_conc_nor.pdf', dpi = 300)

# %%
data6 = pd.read_excel('Phenformin_72hr_normalize.xlsx')
data6.head()
# Out:
#    Conc. (mM) Cell line  Time (hr)  Cell confluence
# 0     0.00000     Empty         72        95.102294
# 1     0.00000     Empty         72        95.102294
# 2     0.00000     Empty         72       100.309981
# 3     0.00000     Empty         72       109.485431
# 4     0.03125     Empty         72        34.965902

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(16,12))

sns.barplot(x="Cell line", y="Cell confluence", data=data6, hue="Conc. (mM)", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Cell line", y="Cell confluence", data=data6, color="0.2", hue="Conc. (mM)", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.2, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='30')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Cell line", size=40)
plt.ylabel("Cell confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('Phenformin growth inhibition', fontsize=30)
plt.savefig('Phenformin growth inhibition  hr_nor.pdf', dpi = 300)

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(16,12))

sns.barplot(x="Conc. (mM)", y="Cell confluence", data=data6, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Conc. (mM)", y="Cell confluence", data=data6, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.2, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='30')

plt.xticks(size=35)
plt.yticks(size=35)

plt.xlabel("Conc. (mM)", size=40)
plt.ylabel("Cell confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('Phenformin growth inhibition', fontsize=30)
plt.savefig('Phenformin growth inhibition 72 hr_conc_nor.pdf', dpi = 300)
