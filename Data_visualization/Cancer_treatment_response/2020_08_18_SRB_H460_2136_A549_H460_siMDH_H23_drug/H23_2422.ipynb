# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")

# %%
data = pd.read_excel('H23_2422.xlsx')
data.head()
# Out:
#    Conc. (uM) Cell line  Cell confluence
# 0      0.0000     Empty        94.958827
# 1      0.0000     Empty       102.831894
# 2      0.0000     Empty       103.233581
# 3      0.0000     Empty        98.975698
# 4      0.3125     Empty        89.495883

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

sns.barplot(x="Conc. (uM)", y="Cell confluence", data=data, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Conc. (uM)", y="Cell confluence", data=data, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.15, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Conc. (uM)", size=40)
plt.ylabel("Confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('H23 2422', fontsize=40)
plt.savefig('H23_2422.pdf', dpi = 300)

# %%
data1 = pd.read_excel('H23_2136.xlsx')
data1.head()
# Out:
#    Conc. (uM) Cell line  Cell confluence
# 0      0.0000     Empty       100.870253
# 1      0.0000     Empty        96.835443
# 2      0.0000     Empty       102.294304
# 3      0.3125     Empty        97.943038
# 4      0.3125     Empty        86.155063

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

sns.barplot(x="Conc. (uM)", y="Cell confluence", data=data1, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Conc. (uM)", y="Cell confluence", data=data1, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.15, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Conc. (uM)", size=40)
plt.ylabel("Confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('H23 2136', fontsize=40)
plt.savefig('H23_2136.pdf', dpi = 300)

# %%
data2 = pd.read_excel('H23_1497.xlsx')
data2.head()
# Out:
#    Conc. (uM) Cell line  Cell confluence
# 0       0.000     Empty       106.333190
# 1       0.000     Empty        96.028338
# 2       0.000     Empty        97.638471
# 3       0.625     Empty        91.391155
# 4       0.625     Empty        95.319880

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

sns.barplot(x="Conc. (uM)", y="Cell confluence", data=data2, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Conc. (uM)", y="Cell confluence", data=data2, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.15, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Conc. (uM)", size=40)
plt.ylabel("Confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('H23 1497', fontsize=40)
plt.savefig('H23_1497.pdf', dpi = 300)
