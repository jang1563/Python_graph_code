# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")

# %%
data = pd.read_excel('A549_siMDH_72hr_direct_20nM.xlsx')
data.head()
# Out:
#     Group Cell line  Time (hr)  Cell confluence
# 0  siCtrl     Empty         72       100.997592
# 1  siCtrl     Empty         72        94.943240
# 2  siCtrl     Empty         72       110.904713
# 3  siCtrl     Empty         72        93.154455
# 4  siMDH1     Empty         72        70.725834

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

sns.barplot(x="Group", y="Cell confluence", data=data, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Group", y="Cell confluence", data=data, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.15, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Treatment", size=40)
plt.ylabel("Confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('A549 siMDH 20 nM direct', fontsize=40)
plt.savefig('A549_20nM_direct_confluence.pdf', dpi = 300)

# %%
data1 = pd.read_excel('A549_siMDH_72hr_direct_40nM.xlsx')
data1.head()
# Out:
#     Group Cell line  Time (hr)  Cell confluence
# 0  siCtrl     Empty         72       104.230533
# 1  siCtrl     Empty         72       101.532802
# 2  siCtrl     Empty         72        98.099326
# 3  siCtrl     Empty         72        96.137339
# 4  siMDH1     Empty         72        66.462293

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

sns.barplot(x="Group", y="Cell confluence", data=data1, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Group", y="Cell confluence", data=data1, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.15, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Treatment", size=40)
plt.ylabel("Confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('A549 siMDH 40 nM direct', fontsize=40)
plt.savefig('A549_40nM_direct_confluence.pdf', dpi = 300)
