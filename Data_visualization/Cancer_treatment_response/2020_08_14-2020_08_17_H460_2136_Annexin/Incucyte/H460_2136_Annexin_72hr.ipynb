# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")


data = pd.read_excel('Annexin_green_object_count.xlsx')
data.head()
# Out:
#    Conc. (uM) Cell line  Green Object Count
# 0         0.0     Empty               33.00
# 1         0.0     Empty               50.50
# 2         0.0     Empty               29.25
# 3         0.0      LKB1               31.00
# 4         0.0      LKB1               16.75

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

sns.barplot(x="Conc. (uM)", y="Green Object Count", data=data, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Conc. (uM)", y="Green Object Count", data=data, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.15, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Conc. (uM)", size=40)
plt.ylabel("Annexin V+ cell", size=40)

sns.set(style="whitegrid")

plt.title('LMT2136 Annexin V', fontsize=40)
plt.savefig('LMT2136 apoptosis_conc.pdf', dpi = 300)

# %%
data1 = pd.read_excel('Annexin_phase.xlsx')
data1.head()
# Out:
#    Conc. (uM) Cell line  Confluence (%)
# 0         0.0     Empty        94.49081
# 1         0.0     Empty        98.22125
# 2         0.0     Empty        97.29299
# 3         0.0      LKB1        97.09540
# 4         0.0      LKB1        94.72523

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

sns.barplot(x="Conc. (uM)", y="Confluence (%)", data=data1, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Conc. (uM)", y="Confluence (%)", data=data1, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.15, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Conc. (uM)", size=40)
plt.ylabel("Confluence (%)", size=40)

sns.set(style="whitegrid")

plt.title('LMT2136 Annexin V', fontsize=40)
plt.savefig('LMT2136 apoptosis_confluence.pdf', dpi = 300)
