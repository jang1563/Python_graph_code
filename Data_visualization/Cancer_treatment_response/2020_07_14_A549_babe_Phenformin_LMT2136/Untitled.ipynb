# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")


data = pd.read_excel('Drug_analysis_normalize.xlsx')
data.head()
# Out:
#    Conc. (uM)  Cell line  Cell confluence
# 0       0.000  Empty-1st        99.952313
# 1       0.000  Empty-1st       103.481164
# 2       0.000  Empty-1st        99.952313
# 3       0.000  Empty-1st        96.614211
# 4       0.625  Empty-1st        86.409156

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(16,12))

sns.barplot(x="Cell line", y="Cell confluence", data=data, hue="Conc. (uM)", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Cell line", y="Cell confluence", data=data, color="0.2", hue="Conc. (uM)", dodge=True)


plt.legend(bbox_to_anchor=(1.1, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='15')

plt.xticks(size=20, rotation=45,ha="right",rotation_mode='anchor')
plt.yticks(size=20)

plt.xlabel("Cell line", size=20)
plt.ylabel("Cell confluence (%)", size=20)

sns.set(style="whitegrid")

plt.title('LMT2136 growth inhibition', fontsize=20)
plt.savefig('LMT2136 growth inhibition_normalize_cell_line.pdf', dpi = 300)

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,10))

sns.barplot(x="Conc. (uM)", y="Cell confluence", data=data, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Conc. (uM)", y="Cell confluence", data=data, color="0.2", hue="Cell line", dodge=True)



plt.legend(bbox_to_anchor=(1.12, 0.8))

plt.setp(ax.get_legend().get_texts(), fontsize='15')

plt.xticks(size=20)
plt.yticks(size=20)

plt.xlabel("Conc. (uM)", size=20)
plt.ylabel("Cell confluence (%)", size=20)

sns.set(style="whitegrid")

plt.title('LMT2136 growth inhibition', fontsize=20)
plt.savefig('LMT2136 growth inhibition_normalize_conc.pdf', dpi = 300)

# %%
data2 = pd.read_excel('Drug_analysis.xlsx')
data2.head()
# Out:
#    Conc. (uM)  Cell line  Cell confluence
# 0       0.000  Empty-1st        99.952313
# 1       0.000  Empty-1st       103.481164
# 2       0.000  Empty-1st        99.952313
# 3       0.000  Empty-1st        96.614211
# 4       0.625  Empty-1st        86.409156

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(16,12))

sns.barplot(x="Cell line", y="Cell confluence", data=data2, hue="Conc. (uM)", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Cell line", y="Cell confluence", data=data2, color="0.2", hue="Conc. (uM)", dodge=True)


plt.legend(bbox_to_anchor=(1.1, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='15')

plt.xticks(size=20, rotation=45,ha="right",rotation_mode='anchor')
plt.yticks(size=20)

plt.xlabel("Cell line", size=20)
plt.ylabel("Cell confluence (%)", size=20)

sns.set(style="whitegrid")

plt.title('LMT2136 growth inhibition', fontsize=20)
plt.savefig('LMT2136 growth inhibition_cell_line.pdf', dpi = 300)

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,10))

sns.barplot(x="Conc. (uM)", y="Cell confluence", data=data2, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Conc. (uM)", y="Cell confluence", data=data2, color="0.2", hue="Cell line", dodge=True)



plt.legend(bbox_to_anchor=(1.12, 0.8))

plt.setp(ax.get_legend().get_texts(), fontsize='15')

plt.xticks(size=20)
plt.yticks(size=20)

plt.xlabel("Conc. (uM)", size=20)
plt.ylabel("Cell confluence (%)", size=20)

sns.set(style="whitegrid")

plt.title('LMT2136 growth inhibition', fontsize=20)
plt.savefig('LMT2136 growth inhibition_conc.pdf', dpi = 300)
