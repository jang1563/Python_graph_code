# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")


data = pd.read_excel('H460_siMDH_72hr_replating.xlsx')
data.head()
# Out:
#     Group Cell line  Time (hr)  Cell confluence
# 0  siCtrl     Empty         72       100.240674
# 1  siCtrl     Empty         72       106.137184
# 2  siCtrl     Empty         72        97.593261
# 3  siCtrl     Empty         72        96.028881
# 4  siMDH1     Empty         72       105.475331

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

sns.barplot(x="Group", y="Cell confluence", data=data, hue="Cell line", capsize=.1, ci="sd", palette="YlGnBu_d")
sns.swarmplot(x="Group", y="Cell confluence", data=data, color="0.2", hue="Cell line", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.15, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=40)
plt.yticks(size=40)

plt.xlabel("Treatment", size=40)
plt.ylabel("Cell confluence (%)", size=40)

sns.set(style="whitegrid")

plt.ylim(40, 120)

plt.title('siMDH growth inhibition', fontsize=40)
plt.savefig('H460_siMDH growth inhibition_normalize_conc_72hr.pdf', dpi = 300)
