# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")


data = pd.read_excel('A549-24hr.xlsx')

# %%
data.head()
# Out:
#    Cell number         Time  Cell confluence
# 0         5000  24 hr (1st)         0.973306
# 1         5000  24 hr (2nd)         0.997947
# 2         5000  24 hr (3rd)         1.028747
# 3         5000  24 hr (4th)         0.967146
# 4         5000  24 hr (5th_         1.059548

# %%
sns.regplot(x="Cell number", y="Cell confluence", data=data)
plt.xlim(0, 50000)

sns.set(font_scale=1.5)

plt.title('A549 confluence 24 hr', fontsize=20)
plt.savefig('A549 confluence 24 hr_regression.pdf', dpi = 300)
