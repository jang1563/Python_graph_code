# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")


data = pd.read_excel('A549_analysis_reg.xlsx')
data.head()
# Out:
#    Cell number   Time  Cell confluence
# 0         5000  24 hr         0.973306
# 1         5000  24 hr         0.997947
# 2         5000  24 hr         1.028747
# 3         5000  24 hr         0.967146
# 4         5000  24 hr         1.059548

# %%
sns.lmplot(x="Cell number", y="Cell confluence", hue = "Time", data=data)

plt.xlim(0, 50000)

sns.set(font_scale=1.5)

plt.title('A549 confluence', fontsize=20)
plt.savefig('A549 confluence reg.pdf', dpi = 300)
