# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")


data = pd.read_excel('H460.xlsx')
data.head()
# Out:
#    Time  Seeding number  Cell confluence
# 0     0              94         0.426648
# 1     2              94         0.479940
# 2     4              94         0.527465
# 3     6              94         0.540606
# 4     8              94         0.568548

# %%
f, ax = plt.subplots(figsize=(12,12))

# %%
sns.set_style("ticks", {"xtick.major.size":8, "ytick.major.size":8})

# %%
sns.axes_style("whitegrid")
# Out:
# {'figure.facecolor': 'white',
#  'axes.labelcolor': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'axes.axisbelow': True,
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'lines.solid_capstyle': 'round',
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'xtick.top': False,
#  'ytick.right': False,
#  'axes.grid': True,
#  'axes.facecolor': 'white',
#  'axes.edgecolor': '.8',
#  'grid.color': '.8',
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True,
#  'xtick.bottom': False,
#  'ytick.left': False}

# %%
g = sns.FacetGrid(data, col="Cell confluence", row="Time")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-53140d7a11b4> in <module>
# ----> 1 g = sns.FacetGrid(data, col="Cell confluence", row="Time")
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
#     322                     warnings.warn(msg.format(MPL_GRIDSPEC_VERSION))
#     323
# --> 324             fig, axes = plt.subplots(nrow, ncol, **kwargs)
#     325             self.axes = axes
#     326
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1210     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
# ...

# %%
f, ax = plt.subplots(figsize=(12,6))

sns.pointplot(x="Time", y="Cell confluence", data=data, hue="Seeding number", ci="sd", color="blue")

plt.legend(bbox_to_anchor=(1.0, 1.0))

# %%
f, ax = plt.subplots(figsize=(12,6))

sns.pointplot(x="Time", y="Cell confluence", data=data, hue="Seeding number", ci="sd", color="blue")

plt.legend(bbox_to_anchor=(1.0, 1.0))

# %%
f, ax = plt.subplots(figsize=(12,6))

sns.pointplot(x="Time", y="Cell confluence", data=data, hue="Seeding number", ci="sd", color="blue")
sns.set_style("ticks", {"xtick.major.size":8, "ytick.major.size":8})

plt.legend(bbox_to_anchor=(1.0, 1.0))

# %%
f, ax = plt.subplots(figsize=(12,6))

sns.pointplot(x="Time", y="Cell confluence", data=data, hue="Seeding number", ci="sd", color="blue")

# Definition of tick_val and tick_lab
tick_val = [0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72]
tick_lab = ['0','12','24', '36', '48', '60', '72', '84', '96', '108', '120', '132', '144']

plt.xticks(tick_val,tick_lab)

plt.legend(bbox_to_anchor=(1.0, 1.0))

# %%
f, ax = plt.subplots(figsize=(12,6))

sns.pointplot(x="Time", y="Cell confluence", data=data, hue="Seeding number", ci="sd", palette="Blues")

# Definition of tick_val and tick_lab
tick_val = [0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72]
tick_lab = ['0','12','24', '36', '48', '60', '72', '84', '96', '108', '120', '132', '144']

plt.xticks(tick_val,tick_lab)

plt.legend(bbox_to_anchor=(1.0, 1.0))


plt.title('H460 growth curve', fontsize=20)
plt.savefig('H460 growth curve.pdf', dpi = 300)

# %%
f, ax = plt.subplots(figsize=(12,6))

sns.pointplot(x="Time", y="Cell confluence", data=data, hue="Seeding number", ci="sd", palette="GnBu_d")

# Definition of tick_val and tick_lab
tick_val = [0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72]
tick_lab = ['0','12','24', '36', '48', '60', '72', '84', '96', '108', '120', '132', '144']

plt.xticks(tick_val,tick_lab)

plt.legend(bbox_to_anchor=(1.0, 1.0))


plt.title('H460 growth curve_2', fontsize=20)
plt.savefig('H460 growth curve_2.pdf', dpi = 300)

# %%
f, ax = plt.subplots(figsize=(12,6))

sns.pointplot(x="Time", y="Cell confluence", data=data, hue="Seeding number", ci="sd", palette="YlGnBu_d")

# Definition of tick_val and tick_lab
tick_val = [0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72]
tick_lab = ['0','12','24', '36', '48', '60', '72', '84', '96', '108', '120', '132', '144']

plt.xticks(tick_val,tick_lab)

plt.legend(bbox_to_anchor=(1.0, 1.0))


plt.title('H460 growth curve_3', fontsize=20)
plt.savefig('H460 growth curve_3.pdf', dpi = 300)

# %%
f, ax = plt.subplots(figsize=(12,6))

sns.pointplot(x="Time", y="Cell confluence", data=data, hue="Seeding number", ci="sd", palette="YlGnBu_d")

# Definition of tick_val and tick_lab
tick_val = [0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72]
tick_lab = ['0','12','24', '36', '48', '60', '72', '84', '96', '108', '120', '132', '144']

plt.xticks(tick_val,tick_lab)
plt.yscale('log')
plt.legend(bbox_to_anchor=(1.0, 1.0))

# %%
f, ax = plt.subplots(figsize=(12,6))

sns.pointplot(x="Time", y="Cell confluence", data=data, hue="Seeding number", ci="sd", palette="YlGnBu_d")

# Definition of tick_val and tick_lab
tick_val = [0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72]
tick_lab = ['0','12','24', '36', '48', '60', '72', '84', '96', '108', '120', '132', '144']

plt.xticks(tick_val,tick_lab)
plt.yscale('log')
plt.legend(bbox_to_anchor=(1.0, 1.0))


plt.ylim(1/10, 120)
# Out:
# (0.1, 120)

# %%
f, ax = plt.subplots(figsize=(12,6))

sns.pointplot(x="Time", y="Cell confluence", data=data, hue="Seeding number", ci="sd", palette="YlGnBu_d")

# Definition of tick_val and tick_lab
tick_val = [0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72]
tick_lab = ['0','12','24', '36', '48', '60', '72', '84', '96', '108', '120', '132', '144']

plt.xticks(tick_val,tick_lab)
plt.yscale('log')
plt.legend(bbox_to_anchor=(1.0, 1.0))


plt.ylim(1/10, 120)
plt.xlim(0, 30)
# Out:
# (0, 30)

# %%
f, ax = plt.subplots(figsize=(12,6))

sns.pointplot(x="Time", y="Cell confluence", data=data, hue="Seeding number", ci="sd", palette="YlGnBu_d", markers=[8, u's', u'X', 11, u'x', u'P', 9, 6, 7], errwidth=0.8, capsize=0.5)

# Definition of tick_val and tick_lab
tick_val = [0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72]
tick_lab = ['0','12','24', '36', '48', '60', '72', '84', '96', '108', '120', '132', '144']

plt.xticks(tick_val,tick_lab)

plt.legend(bbox_to_anchor=(1.0, 1.0))

plt.title('H460 growth curve_4', fontsize=20)
plt.savefig('H460 growth curve_4.pdf', dpi = 300)

# %%
#[0, 1, 2, 3, 4, u'D', 6, 7, 8, u's', u'|', 11, u'None', u'P', 9, u'x', u'X', 5, u'_', u'^', u' ', None, u'd', u'h', u'+', u'*', u',', u'o', u'.', u'1', u'p', u'3', u'2', u'4', u'H', u'v', u'', u'8', 10, u'&lt;', u'&gt;']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-aa003b3e909b> in <module>
# ----> 1 all_shapes=markers.MarkerStyle.markers.keys()
#
# NameError: name 'markers' is not defined

# %%
f, ax = plt.subplots(figsize=(12,6))

sns.pointplot(x="Time", y="Cell confluence", data=data, hue="Seeding number", ci="sd", palette="YlGnBu_d", markers=[8, u's', u'X', 11, u'x', u'P', 9, 6, 7], errwidth=0.5, capsize=0.3)

# Definition of tick_val and tick_lab
tick_val = [0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72]
tick_lab = ['0','12','24', '36', '48', '60', '72', '84', '96', '108', '120', '132', '144']

plt.xticks(tick_val,tick_lab)
plt.yscale('log')
plt.legend(bbox_to_anchor=(1.0, 1.0))


plt.ylim(1/10, 120)
plt.xlim(0, 30)

plt.title('H460 growth curve_log', fontsize=20)
plt.savefig('H460 growth curve_log.pdf', dpi = 300)

# %%
f, ax = plt.subplots(figsize=(12,6))

sns.pointplot(x="Time", y="Cell confluence", data=data, hue="Seeding number", ci="sd", palette="YlGnBu_d", markers=[8, u's', u'X', 11, u'x', u'P', 9, 6, 7], errwidth=0.8, capsize=0.5)

# Definition of tick_val and tick_lab
tick_val = [0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72]
tick_lab = ['0','12','24', '36', '48', '60', '72', '84', '96', '108', '120', '132', '144']

plt.xticks(tick_val,tick_lab, size=20)
plt.yticks(size=20)

plt.xlabel("Time", size=20)
plt.ylabel("Cell confluence (%)", size=20)

plt.legend(bbox_to_anchor=(1.0, 1.0))

plt.title('H460 growth curve_resize', fontsize=20)
plt.savefig('H460 growth curve_resize.pdf', dpi = 300)

# %%
f, ax = plt.subplots(figsize=(12,6))

sns.pointplot(x="Time", y="Cell confluence", data=data, hue="Seeding number", ci="sd", palette="YlGnBu_d", markers=[8, u's', u'X', 11, u'x', u'P', 9, 6, 7], errwidth=0.8, capsize=0.5)

# Definition of tick_val and tick_lab
tick_val = [0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72]
tick_lab = ['0','12','24', '36', '48', '60', '72', '84', '96', '108', '120', '132', '144']

plt.xticks(tick_val,tick_lab, size=20)
plt.yticks(size=20)

plt.xlabel("Time", size=20)
plt.ylabel("Cell confluence (%)", size=20)

plt.legend(bbox_to_anchor=(1.0, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='15')

plt.title('H460 growth curve_resize', fontsize=20)
plt.savefig('H460 growth curve_resize.pdf', dpi = 300)

# %%
f, ax = plt.subplots(figsize=(12,6))

sns.pointplot(x="Time", y="Cell confluence", data=data, hue="Seeding number", ci="sd", palette="YlGnBu_d", markers=[8, u's', u'X', 11, u'x', u'P', 9, 6, 7], errwidth=0.5, capsize=0.3)

# Definition of tick_val and tick_lab
tick_val = [0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72]
tick_lab = ['0','12','24', '36', '48', '60', '72', '84', '96', '108', '120', '132', '144']


plt.yscale('log')
plt.legend(bbox_to_anchor=(1.0, 1.0))

# Definition of tick_val and tick_lab
tick_val = [0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66, 72]
tick_lab = ['0','12','24', '36', '48', '60', '72', '84', '96', '108', '120', '132', '144']

plt.xticks(tick_val,tick_lab, size=20)
plt.yticks(size=20)



plt.ylim(1/10, 120)
plt.xlim(0, 36)

plt.xlabel("Time", size=20)
plt.ylabel("Cell confluence (%)", size=20)

plt.setp(ax.get_legend().get_texts(), fontsize='15')

plt.title('H460 growth curve_log_resize', fontsize=20)
plt.savefig('H460 growth curve_log_resize.pdf', dpi = 300)
