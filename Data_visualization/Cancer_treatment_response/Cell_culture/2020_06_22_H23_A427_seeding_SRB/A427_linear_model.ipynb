# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")


data = pd.read_excel('A427_analysis_reg.xlsx')
data.head()
# Out:
#    Cell number   Time  Cell confluence
# 0         5000  24 hr         0.958254
# 1         5000  24 hr         1.015180
# 2         5000  24 hr         0.958254
# 3         5000  24 hr         1.024668
# 4         5000  24 hr         1.043643

# %%
sns.lmplot(x="Cell number", y="Cell confluence", hue = "Time", data=data)

plt.xlim(0, 50000)

sns.set(font_scale=1.5)

plt.title('A427 confluence', fontsize=20)
plt.savefig('A427 confluence reg.pdf', dpi = 300)
