# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")


data = pd.read_excel('2305_bar_graph.xlsx')

# %%
data.head()
# Out:
#    Conc. (uM)  normalized A540
# 0        0.00         0.988051
# 1        1.25         0.948469
# 2        2.50         0.848394
# 3        5.00         0.554145
# 4       10.00         0.076176

# %%
sns.barplot(x="Conc. (uM)", y="normalized A540", data=data, capsize=.3, ci="sd")
sns.swarmplot(x="Conc. (uM)", y="normalized A540", data=data, color="0", alpha=.35)

plt.show()

# %%
sns.barplot(x="Conc. (uM)", y="normalized A540", data=data, capsize=.3, ci="sd")
sns.swarmplot(x="Conc. (uM)", y="normalized A540", data=data, color="0", alpha=.35)

plt.title('H2009 with 2305', fontsize=20)
plt.savefig('H2009_2305', dpi = 300)
