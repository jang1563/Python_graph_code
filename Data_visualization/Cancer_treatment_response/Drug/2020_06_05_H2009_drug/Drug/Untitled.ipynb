# %%
import numpy as np
import pandas as pd



import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

data = pd.read_excel('Drug.xlsx')

data.head()

df = data.pivot('Conc. (uM)', 'Drug', 'A540')

df.head()
# Out:
# Drug        2136 1st  2136 2nd  2136 3rd  2305 1st  2305 2nd  2305 3rd  \
# Conc. (uM)
# 0.00        0.990984  1.082645  0.926371  1.082050  0.735928  1.182022
# 1.25        0.519159  0.510894  0.408715  0.190703  0.231868  0.236908
# 2.50        0.148009  0.123967  0.108941  0.162139  0.185662  0.158779
# 5.00        0.172051  0.228400  0.168295  0.095771  0.084850  0.089051
# 10.00       0.102179  0.119459  0.123216  0.036124  1.185382  0.044525
#
# Drug        2422 1st  2422 2nd  2422 3rd
# Conc. (uM)
# 0.00        1.028764  1.009339  0.968995
# 1.25        0.026149  0.398207  0.418379
# 2.50        1.057901  0.076205  0.082182
# 5.00        0.045573  0.086664  0.229361
# 10.00       0.033620  0.032126  0.023160

# %%
sns.heatmap(df, annot=True, fmt='.2f')
plt.title('Heatmap of H2009 cell', fontsize=20)
plt.show()

# %%
sns.heatmap(df, annot=True, fmt='.2f')
plt.title('Heatmap of H2009 cell', fontsize=20)
plt.savefig('H2009_drug_300dpi', dpi = 300)
