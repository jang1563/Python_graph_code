# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")


data = pd.read_excel('H23_LMT2136_analysis.xlsx')
data.head()
# Out:
#    Conc. (uM)  Cell seeding number  Cell confluence
# 0     0.00000                 3000       105.895954
# 1     0.00000                 3000       107.283237
# 2     0.00000                 3000        94.104046
# 3     0.00000                 3000        92.716763
# 4     0.30625                 3000       109.595376

# %%
ax = sns.barplot(x="Conc. (uM)", y="Cell confluence", data=data, hue="Cell seeding number", capsize=.3, ci="sd")
sns.swarmplot(x="Conc. (uM)", y="Cell confluence", data=data, color="0.2", hue="Cell seeding number", dodge=True)

sns.set(font_scale=0.7)

plt.title('H23 drug treatment 72 hr', fontsize=20)
plt.savefig('H23 drug treatment 72 hr_bar.pdf', dpi = 300)
