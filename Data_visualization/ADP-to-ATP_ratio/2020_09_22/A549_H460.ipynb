# %%
import seaborn as sns, matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

sns.set(style="whitegrid")

# %%
data1 = pd.read_excel('A549_6hr.xlsx')
data1.head()
# Out:
#    Conc. (nM) Cell line  Time (hr)  Drug   ADP/ATP
# 0         0.0      A549          3  1497  1.035109
# 1         0.0      A549          3  1497  0.962531
# 2         0.0      A549          3  1497  1.002360
# 3         2.5      A549          3  1497  1.074100
# 4         2.5      A549          3  1497  1.113983

# %%
data2 = pd.read_excel('H460_6hr.xlsx')
data2.head()
# Out:
#    Conc. (nM) Cell line  Time (hr)  Drug   ADP/ATP
# 0         0.0      H460          6  1497  0.983137
# 1         0.0      H460          6  1497  1.006060
# 2         0.0      H460          6  1497  1.010803
# 3         2.5      H460          6  1497  1.059381
# 4         2.5      H460          6  1497  1.044680

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

colors = ['#d9d9d9', '#2171b5', '#6baed6', '#bdd7e7']

sns.set_palette(sns.color_palette(colors))

sns.barplot(x="Drug", y="ADP/ATP", hue="Conc. (nM)", data=data1, capsize=.1, ci="sd")
sns.swarmplot(x="Drug", y="ADP/ATP", data=data1, hue="Conc. (nM)", color="0.2", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.11, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=40)
plt.yticks(size=40)


plt.xlabel("Drug", size=40)
plt.ylabel("ADP/ATP", size=40)

plt.savefig('ADP-to-ATP_A549_drug_6hr.pdf', dpi = 300)

# %%
sns.axes_style("whitegrid")

f, ax = plt.subplots(figsize=(22,12))

colors = ['#d9d9d9', '#bdd7e7', '#6baed6', '#2171b5']

sns.set_palette(sns.color_palette(colors))

sns.barplot(x="Drug", y="ADP/ATP", hue="Conc. (nM)", data=data2, capsize=.1, ci="sd")
sns.swarmplot(x="Drug", y="ADP/ATP", hue="Conc. (nM)", data=data2, color="0.2", size=15, dodge=True)


plt.legend(bbox_to_anchor=(1.11, 1.0))

plt.setp(ax.get_legend().get_texts(), fontsize='40')

plt.xticks(size=40)
plt.yticks(size=40)


plt.xlabel("Drug", size=40)
plt.ylabel("ADP/ATP", size=40)

plt.savefig('ADP-to-ATP_H460_drug_6hr.pdf', dpi = 300)
